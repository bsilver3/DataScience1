# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.4'

# %%
df = pd.read_csv('SaccadesDataset.csv')
df.head()
# Out:
#    Unnamed: 0  Participant  Block Condition  Trial     RT  Correct  \
# 0          65            1      1        AV      1  0.911        1
# 1          66            1      1        AV      2  2.824        1
# 2          67            1      1        AV      3  1.866        1
# 3          68            1      1        AV      4  0.771        1
# 4          69            1      1        AV      5  0.953        0
#
#    Orientation  Agegr  Sacstart  Sacend  Sacduration  Xstart  Ystart    Xend  \
# 0            0  Young       195     258           64   877.5   381.9  1012.1
# 1            0  Young       960     967            8   990.8   261.4   969.5
# 2            0  Young       216     255           40   822.0   260.4   747.9
# 3            0  Young       157     181           25   851.3   300.9   961.7
# 4            0  Young       688     706           19   938.5   276.2   964.7
#
#     Yend  Amplitude  Velocity
# 0  272.9       3.74       223
# 1  254.6       0.43        57
# ...
