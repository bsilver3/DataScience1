# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("apstatsdata.csv")

# %%
df.head()
# Out:
#   First Name  Last Name  Age (Years)  Total Time in Jail (Days)
# 0     miguel  hernandez           69                          1
# 1      kevon      dixon           34                         10
# 2         ed      philo           24                          1
# 3     marsha      miles           44                          1
# 4     edward     riddle           41                          6

# %%
sns.set(rc={"figure.figsize":(23.7,8.27)})
sns.set_style("whitegrid")

# %%
sns.boxplot(data=df, x="Age (Years)")
# Out:
# <AxesSubplot:xlabel='Age (Years)'>

# %%
sns.boxplot(data=df, x="Total Time in Jail (Days)")
# Out:
# <AxesSubplot:xlabel='Total Time in Jail (Days)'>

# %%
sns.scatterplot(data=df, x="Age (Years)", y="Total Time in Jail (Days)")
# Out:
# <AxesSubplot:xlabel='Age (Years)', ylabel='Total Time in Jail (Days)'>

# %%
sns.regplot(data=df, x="Age (Years)", y="Total Time in Jail (Days)")
# Out:
# <AxesSubplot:xlabel='Age (Years)', ylabel='Total Time in Jail (Days)'>
